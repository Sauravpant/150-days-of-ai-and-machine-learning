# %%
import pandas as pd

# %%
df=pd.read_csv("../data/nepal-earthquake-severity-index-latest.csv")
df.head(10)
# Out:
#          P_CODE            VDC_NAME   DISTRICT   REGION  Hazard (Intensity)  \
# 0  C-BAG-27-031       KathmanduN.P.  Kathmandu  Central                2.17
# 1  C-BAG-25-027        LalitpurN.P.   Lalitpur  Central                1.72
# 2  C-NAR-35-005      BharatpurN. P.   Chitawan  Central                2.21
# 3  C-BAG-26-012  MadhyapurThimiN.P.  Bhaktapur  Central                2.45
# 4  C-BAG-27-028             Jorpati  Kathmandu  Central                1.91
# 5  C-BAG-26-003       BhaktapurN.P.  Bhaktapur  Central                1.82
# 6  W-GAN-36-050  PrithbinarayanN.P.     Gorkha  Western                3.48
# 7  C-JAN-20-025        KamalamiN.P.   Sindhuli  Central                2.54
# 8  C-JAN-20-026           Kapilakot   Sindhuli  Central                8.02
# 9  C-BAG-27-033        KirtipurN.P.  Kathmandu  Central                1.35
#
#    Exposure  Housing  Poverty  Vulnerability  Severity  Severity Normalized  \
# ...

# %% [markdown]
# ### DataFrame methods

# %%
df.shape
# Out:
# (3986, 12)

# %%
df.size
# Out:
# 47832

# %%
df.get(['DISTRICT']).head(7)
# Out:
#     DISTRICT
# 0  Kathmandu
# 1   Lalitpur
# 2   Chitawan
# 3  Bhaktapur
# 4  Kathmandu
# 5  Bhaktapur
# 6     Gorkha

# %% [markdown]
# ### Indexing

# %%
rows=df.head(4)
rows
# Out:
#          P_CODE            VDC_NAME   DISTRICT   REGION  Hazard (Intensity)  \
# 0  C-BAG-27-031       KathmanduN.P.  Kathmandu  Central                2.17
# 1  C-BAG-25-027        LalitpurN.P.   Lalitpur  Central                1.72
# 2  C-NAR-35-005      BharatpurN. P.   Chitawan  Central                2.21
# 3  C-BAG-26-012  MadhyapurThimiN.P.  Bhaktapur  Central                2.45
#
#    Exposure  Housing  Poverty  Vulnerability  Severity  Severity Normalized  \
# 0     10.00     8.86     1.82           5.34      4.88              10.0000
# 1      2.26     8.40     0.82           4.61      2.62               5.3707
# 2      1.47     5.38     2.53           3.96      2.34               4.8083
# 3      0.85     8.23     0.89           4.56      2.12               4.3447
#
#   Severity category
# 0           Highest
# 1           Highest
# 2           Highest
# 3           Highest

# %%
rows.index=['A','B','C','D']
rows
# Out:
#          P_CODE            VDC_NAME   DISTRICT   REGION  Hazard (Intensity)  \
# A  C-BAG-27-031       KathmanduN.P.  Kathmandu  Central                2.17
# B  C-BAG-25-027        LalitpurN.P.   Lalitpur  Central                1.72
# C  C-NAR-35-005      BharatpurN. P.   Chitawan  Central                2.21
# D  C-BAG-26-012  MadhyapurThimiN.P.  Bhaktapur  Central                2.45
#
#    Exposure  Housing  Poverty  Vulnerability  Severity  Severity Normalized  \
# A     10.00     8.86     1.82           5.34      4.88              10.0000
# B      2.26     8.40     0.82           4.61      2.62               5.3707
# C      1.47     5.38     2.53           3.96      2.34               4.8083
# D      0.85     8.23     0.89           4.56      2.12               4.3447
#
#   Severity category
# A           Highest
# B           Highest
# C           Highest
# D           Highest

# %%
rows.loc['A'] #Selects rows by index name
# Out:
# P_CODE                  C-BAG-27-031
# VDC_NAME               KathmanduN.P.
# DISTRICT                   Kathmandu
# REGION                       Central
# Hazard (Intensity)              2.17
# Exposure                        10.0
# Housing                         8.86
# Poverty                         1.82
# Vulnerability                   5.34
# Severity                        4.88
# Severity Normalized             10.0
# Severity category            Highest
# Name: A, dtype: object

# %%
rows.iloc[0]  ##Selects rows by index count
# Out:
# P_CODE                  C-BAG-27-031
# VDC_NAME               KathmanduN.P.
# DISTRICT                   Kathmandu
# REGION                       Central
# Hazard (Intensity)              2.17
# Exposure                        10.0
# Housing                         8.86
# Poverty                         1.82
# Vulnerability                   5.34
# Severity                        4.88
# Severity Normalized             10.0
# Severity category            Highest
# Name: A, dtype: object

# %% [markdown]
# #### Boolean Indexing

# %%
df
# Out:
#             P_CODE               VDC_NAME     DISTRICT       REGION  \
# 0     C-BAG-27-031          KathmanduN.P.    Kathmandu      Central
# 1     C-BAG-25-027           LalitpurN.P.     Lalitpur      Central
# 2     C-NAR-35-005         BharatpurN. P.     Chitawan      Central
# 3     C-BAG-26-012     MadhyapurThimiN.P.    Bhaktapur      Central
# 4     C-BAG-27-028                Jorpati    Kathmandu      Central
# ...            ...                    ...          ...          ...
# 3981  F-SET-70-052  Khaptad National Park         Doti  Far-Western
# 3982  M-BHE-58-033   Royal Bardiya Nation      Bardiya  Mid-Western
# 3983  W-LUM-48-075   Royal Chitawan Natio  Nawalparasi      Western
# 3984  W-LUM-49-072    Lumbini Development    Rupandehi      Western
# 3985           NaN                    NaN          NaN          NaN
#
#       Hazard (Intensity)  Exposure  Housing  Poverty  Vulnerability  Severity  \
# ...

# %%
df[df['REGION']=='Far-Western'].head(4)
# Out:
#             P_CODE VDC_NAME DISTRICT       REGION  Hazard (Intensity)  \
# 3067  F-SET-67-026   Sapata   Bajura  Far-Western                 0.0
# 3137  F-SET-67-011   Gotree   Bajura  Far-Western                 0.0
# 3167  F-SET-67-002   Baddhu   Bajura  Far-Western                 0.0
# 3198  F-SET-67-003      Bai   Bajura  Far-Western                 0.0
#
#       Exposure  Housing  Poverty  Vulnerability  Severity  \
# 3067      0.06     8.08      8.8           8.44      0.04
# 3137      0.06     8.08      8.8           8.44      0.04
# 3167      0.05     8.08      8.8           8.44      0.03
# 3198      0.03     8.08      8.8           8.44      0.03
#
#       Severity Normalized Severity category
# 3067               0.0849            Lowest
# 3137               0.0736            Lowest
# 3167               0.0696            Lowest
# 3198               0.0661            Lowest

# %%
df[(df['REGION']=='Far-Western') & (df['DISTRICT']=='Dadeldhura')].tail(4)
# Out:
#             P_CODE   VDC_NAME    DISTRICT       REGION  Hazard (Intensity)  \
# 3626  F-MAH-73-018  Nawadurga  Dadeldhura  Far-Western                 0.0
# 3642  F-MAH-73-009     Chipur  Dadeldhura  Far-Western                 0.0
# 3657  F-MAH-73-020    Samejee  Dadeldhura  Far-Western                 0.0
# 3669  F-MAH-73-007  Bhadrapur  Dadeldhura  Far-Western                 0.0
#
#       Exposure  Housing  Poverty  Vulnerability  Severity  \
# 3626      0.03     8.09     5.89           6.99       0.0
# 3642      0.03     8.09     5.89           6.99       0.0
# 3657      0.03     8.09     5.89           6.99       0.0
# 3669      0.02     8.09     5.89           6.99       0.0
#
#       Severity Normalized Severity category
# 3626                  0.0            Lowest
# 3642                  0.0            Lowest
# 3657                  0.0            Lowest
# 3669                  0.0            Lowest

# %% [markdown]
# ### Setting and Resetting Index

# %%
df.set_index('REGION',inplace=True)
df
# Out:
#                    P_CODE               VDC_NAME     DISTRICT  \
# REGION
# Central      C-BAG-27-031          KathmanduN.P.    Kathmandu
# Central      C-BAG-25-027           LalitpurN.P.     Lalitpur
# Central      C-NAR-35-005         BharatpurN. P.     Chitawan
# Central      C-BAG-26-012     MadhyapurThimiN.P.    Bhaktapur
# Central      C-BAG-27-028                Jorpati    Kathmandu
# ...                   ...                    ...          ...
# Far-Western  F-SET-70-052  Khaptad National Park         Doti
# Mid-Western  M-BHE-58-033   Royal Bardiya Nation      Bardiya
# Western      W-LUM-48-075   Royal Chitawan Natio  Nawalparasi
# Western      W-LUM-49-072    Lumbini Development    Rupandehi
# NaN                   NaN                    NaN          NaN
#
#              Hazard (Intensity)  Exposure  Housing  Poverty  Vulnerability  \
# REGION
# Central                    2.17     10.00     8.86     1.82           5.34
# ...

# %%
df.reset_index(inplace=True,drop=True)
df
# Out:
#             P_CODE               VDC_NAME     DISTRICT  Hazard (Intensity)  \
# 0     C-BAG-27-031          KathmanduN.P.    Kathmandu                2.17
# 1     C-BAG-25-027           LalitpurN.P.     Lalitpur                1.72
# 2     C-NAR-35-005         BharatpurN. P.     Chitawan                2.21
# 3     C-BAG-26-012     MadhyapurThimiN.P.    Bhaktapur                2.45
# 4     C-BAG-27-028                Jorpati    Kathmandu                1.91
# ...            ...                    ...          ...                 ...
# 3981  F-SET-70-052  Khaptad National Park         Doti                0.00
# 3982  M-BHE-58-033   Royal Bardiya Nation      Bardiya                0.00
# 3983  W-LUM-48-075   Royal Chitawan Natio  Nawalparasi                0.84
# 3984  W-LUM-49-072    Lumbini Development    Rupandehi                0.02
# 3985           NaN                    NaN          NaN                 NaN
#
#       Exposure  Housing  Poverty  Vulnerability  Severity  \
# ...
